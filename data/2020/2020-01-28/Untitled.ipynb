# %% [markdown]
# ## Tasks/Questions
#
# - T: plot all the trees graphically, improving on our old Meteorite graphing code

# %%
import pandas as pd

import numpy as np
import geopandas
import folium
from folium import plugins
from folium.plugins import HeatMap
from folium.plugins import MarkerCluster
from tqdm import tqdm

# %% [markdown]
# ## Data Injestion

# %%
df = pd.read_csv("sf_trees.csv")
# Out:
# /home/ghilston/Git/tidytuesday/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192987 entries, 0 to 192986
# Data columns (total 12 columns):
# tree_id         192987 non-null int64
# legal_status    192933 non-null object
# species         192987 non-null object
# address         191500 non-null object
# site_order      191353 non-null float64
# site_info       192987 non-null object
# caretaker       192987 non-null object
# date            68377 non-null object
# dbh             151168 non-null float64
# plot_size       142974 non-null object
# latitude        190155 non-null float64
# longitude       190155 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 17.7+ MB

# %%
df.describe()
# Out:
#              tree_id     site_order            dbh       latitude  \
# count  192987.000000  191353.000000  151168.000000  190155.000000
# mean   126529.214071       4.579118       9.953767      37.766260
# std     79317.040625      12.515736      29.364079       0.249752
# min         1.000000     -50.000000       0.000000      37.509004
# 25%     52601.500000       1.000000       3.000000      37.740320
# 50%    120862.000000       2.000000       7.000000      37.760244
# 75%    202607.500000       4.000000      12.000000      37.779639
# max    261546.000000     501.000000    9999.000000      47.270219
#
#            longitude
# count  190155.000000
# mean     -122.445586
# std         0.415291
# min      -138.283861
# 25%      -122.454299
# 50%      -122.431402
# 75%      -122.412955
# max      -122.366622

# %%
df.head()
# Out:
#    tree_id    legal_status                                 species  \
# 0    53719  Permitted Site                              Tree(s) ::
# 1    30313  Permitted Site                              Tree(s) ::
# 2    30312  Permitted Site                              Tree(s) ::
# 3    30314  DPW Maintained  Pittosporum undulatum :: Victorian Box
# 4    30315  Permitted Site  Acacia melanoxylon :: Blackwood Acacia
#
#               address  site_order                     site_info caretaker  \
# 0     2963 Webster St         1.0  Sidewalk: Curb side : Cutout   Private
# 1     501 Arkansas St         3.0  Sidewalk: Curb side : Cutout   Private
# 2     501 Arkansas St         2.0  Sidewalk: Curb side : Cutout   Private
# 3     501 Arkansas St         1.0  Sidewalk: Curb side : Cutout   Private
# 4  1190 Sacramento St         5.0  Sidewalk: Curb side : Cutout   Private
#
#          date   dbh plot_size   latitude   longitude
# 0  1955-09-19   NaN       NaN  37.797869 -122.434054
# 1  1955-10-20   NaN       NaN  37.759838 -122.398119
# 2  1955-10-20   NaN       NaN  37.759838 -122.398119
# 3  1955-10-20  16.0       NaN  37.759772 -122.398109
# 4  1955-10-24   NaN       NaN  37.792650 -122.412449

# %% [markdown]
# ## Geo Spatial

# %%
# Create a new dataframe of just the lat and long columns
geo_df = df.dropna(axis=0, how="any", subset=["latitude", "longitude"])

# we'll preserve the id from the data set
geo_df = geo_df.set_index("tree_id")

# %%
geo_df
# Out:
#            legal_status                                        species  \
# tree_id
# 53719    Permitted Site                                     Tree(s) ::
# 30313    Permitted Site                                     Tree(s) ::
# 30312    Permitted Site                                     Tree(s) ::
# 30314    DPW Maintained         Pittosporum undulatum :: Victorian Box
# 30315    Permitted Site         Acacia melanoxylon :: Blackwood Acacia
# ...                 ...                                            ...
# 115063   DPW Maintained                                             ::
# 234951   DPW Maintained         Pittosporum undulatum :: Victorian Box
# 17192    DPW Maintained      Magnolia grandiflora :: Southern Magnolia
# 228173   DPW Maintained          Lophostemon confertus :: Brisbane Box
# 121713   DPW Maintained  Liquidambar styraciflua :: American Sweet Gum
#
#                       address  site_order                     site_info  \
# tree_id
# 53719         2963 Webster St         1.0  Sidewalk: Curb side : Cutout
# 30313         501 Arkansas St         3.0  Sidewalk: Curb side : Cutout
# 30312         501 Arkansas St         2.0  Sidewalk: Curb side : Cutout
# 30314         501 Arkansas St         1.0  Sidewalk: Curb side : Cutout
# 30315      1190 Sacramento St         5.0  Sidewalk: Curb side : Cutout
# ...                       ...         ...                           ...
# 115063            70 Coral Rd         3.0  Sidewalk: Curb side : Cutout
# 234951           4724 25th St         1.0  Sidewalk: Curb side : Cutout
# 17192        2235X Octavia St         1.0               Median : Cutout
# 228173         790 Florida St         2.0  Sidewalk: Curb side : Cutout
# 121713   880 Pennsylvania Ave         9.0  Sidewalk: Curb side : Cutout
#
#         caretaker        date   dbh  plot_size   latitude   longitude
# tree_id
# 53719     Private  1955-09-19   NaN        NaN  37.797869 -122.434054
# 30313     Private  1955-10-20   NaN        NaN  37.759838 -122.398119
# 30312     Private  1955-10-20   NaN        NaN  37.759838 -122.398119
# 30314     Private  1955-10-20  16.0        NaN  37.759772 -122.398109
# 30315     Private  1955-10-24   NaN        NaN  37.792650 -122.412449
# ...           ...         ...   ...        ...        ...         ...
# 115063        DPW         NaN   NaN        NaN  37.753839 -122.399069
# 234951    Private         NaN   8.0  Width 2ft  37.749267 -122.442046
# 17192         DPW         NaN  12.0         20  37.792795 -122.427894
# 228173    Private         NaN   2.0  Width 3ft  37.759348 -122.410957
# 121713    Private         NaN   3.0        NaN  37.755647 -122.393055
#
# [190155 rows x 11 columns]

# %%
# Create and register a new `tqdm` instance with `pandas`
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()

# %%
def visualize_geo_spatial_data(df, latitude_column_name, longitude_column_name, file_name_to_save_to="markers_map.html"):
    our_map = folium.Map(tiles="CartoDB dark_matter")
    our_map_cluster = MarkerCluster().add_to(our_map)

    df.progress_apply(
        lambda row:folium.Marker(
            location=[row[latitude_column_name],
            row[longitude_column_name]], 
            radius=10,
            tooltip=row.name,
            popup=row.to_frame().to_html()
        ).add_to(our_map_cluster), axis=1
    )

    our_map.save(file_name_to_save_to)
    our_map.fit_bounds(our_map.get_bounds())
    return our_map

# %%
visualize_geo_spatial_data(geo_df, "latitude", "longitude")
# Out:
# 100%|██████████| 190155/190155 [04:22<00:00, 724.33it/s]
